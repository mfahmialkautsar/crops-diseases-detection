# %% [markdown]
# # Import

# %%
import os
import shutil
from pathlib import Path
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Flatten, Dropout, Dense, Input
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
import pandas as pd

# %%
# dotenv
try:
  from dotenv import load_dotenv
except ModuleNotFoundError:
  # !pip install python-dotenv
  from dotenv import load_dotenv
load_dotenv()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-dotenv
#   Downloading python_dotenv-0.20.0-py3-none-any.whl (17 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-0.20.0
# True

# %% [markdown]
# # Files

# %% [markdown]
# ## Variables

# %%
data_folder = 'crops_diseases'
DATA_DIR = os.path.join('/',
                        'content',
                        data_folder,
                        )
LABELLED_DIR = os.path.join(
    DATA_DIR, 'BangladeshiCrops', 'BangladeshiCrops', 'Crop___Disease')
DRIVE_DIR = os.environ.get('DRIVE_DIR', '')

# %% [markdown]
# ## Kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download nafishamoin/new-bangladeshi-crop-disease --unzip -p {data_folder}
# Out:
# Downloading new-bangladeshi-crop-disease.zip to crops_diseases
# 100% 2.32G/2.33G [00:24<00:00, 154MB/s]
# 100% 2.33G/2.33G [00:24<00:00, 102MB/s]

# %% [markdown]
# ## Google Colaboratory

# %%
is_colab = False
try:
  from google.colab import drive
  drive.mount('/content/drive')
  is_colab = True
  Path(DRIVE_DIR).mkdir(parents=True, exist_ok=True)
except:
  pass
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Clean Dirs

# %%
for subdir, dirs, files in os.walk(DATA_DIR):
    for file in files:
        if file == '.DS_Store':
            os.remove(os.path.join(subdir, file))

# %% [markdown]
# # Preprocess

# %% [markdown]
# ## Variables

# %%
EPOCHS = 100
LEARNING_RATE = 1e-3
BS = 32
width = 200
height = 200
target_size = (width, height)
depth = 3
color_mode = 'rgb'
if depth == 1:
  color_mode = 'grayscale'
elif depth == 4:
  color_mode = 'rgba'

# %%
def get_slices(data_dir):
    data = []
    labels = []
    for subdir, dirs, files in os.walk(data_dir):
        for f in files:
            label = '__'.join(os.path.relpath(
                subdir, data_dir).split(os.path.sep))
            img_path = os.path.join(subdir, f)
            data.append(img_path)
            labels.append(label)
    return np.array(data), np.array(labels)


def preprocess_image(img_path, color_mode='rgb', target_size=(256, 256)):
    img = tf.keras.utils.load_img(img_path, color_mode=color_mode, target_size=target_size)
    img = tf.keras.utils.img_to_array(img)
    return img

# %% [markdown]
# ## Augmentation

# %%
fill_mode = 'nearest'
train_augmentation = Sequential([
    layers.Rescaling(1./255),
    layers.RandomFlip('horizontal_and_vertical'),
    layers.RandomTranslation(
        height_factor=0.15, width_factor=0.15, fill_mode=fill_mode),
    layers.RandomRotation(0.45, fill_mode=fill_mode),
    layers.RandomZoom(0.2, fill_mode=fill_mode),
    layers.RandomContrast(0.2),
])
val_augmentation = Sequential([
    layers.Rescaling(1./255),
])

# %% [markdown]
# ### From Single image folder with shuffle

# %% [markdown]
# #### Slices

# %%
images, labels = get_slices(LABELLED_DIR)

# %%
columns = ['image', 'label']
column_image = columns[0]
column_label = columns[1]
df = pd.DataFrame(
    {column_image: images, column_label: labels}, columns=columns)
classes = sorted(df[column_label].unique())
n_classes = len(classes)

# %%
# Preprocess labels
lb = LabelBinarizer()
lb.fit(classes)
# Out:
# LabelBinarizer()

# %%
train_df, val_test_df = train_test_split(
    df, test_size=0.15, random_state=123, stratify=df[column_label])
val_df, test_df = train_test_split(
    val_test_df, test_size=0.4, random_state=123, stratify=val_test_df[column_label])

# %%
print(f'Train: {len(train_df)}')
print(f'Validation: {len(val_df)}')
print(f'Test: {len(test_df)}')
print(f'Classes: {n_classes}')
# Out:
# Train: 11070
# Validation: 1172
# Test: 782
# Classes: 14

# %% [markdown]
# #### ImageDataGenerator

# %%
# train_datagen = ImageDataGenerator(
#     rescale=1./255,
#     rotation_range=45,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     shear_range=0.15,
#     zoom_range=0.2,
#     horizontal_flip=True,
#     vertical_flip=True,
# )

# val_datagen = ImageDataGenerator(
#     rescale=1./255,
# )

# %% [markdown]
# ##### flow

# %%
# train_generator = train_datagen.flow(train_images, train_labels, batch_size=BS)
# val_generator = val_datagen.flow(val_images, val_labels, batch_size=BS)

# %% [markdown]
# ##### flow_from_dataframe

# %%
# train_generator = train_datagen.flow_from_dataframe(train_df,
#                                               x_col=columns[0],
#                                               y_col=columns[1],
#                                               target_size=target_size,
#                                               batch_size=BS,
# )

# val_generator = val_datagen.flow_from_dataframe(val_df,
#                                           x_col=columns[0],
#                                           y_col=columns[1],
#                                           target_size=target_size,
#                                           batch_size=BS,
# )

# test_generator = val_datagen.flow_from_dataframe(test_df,
#                                           x_col=columns[0],
#                                           y_col=columns[1],
#                                           target_size=target_size,
#                                           batch_size=BS,
# )

# %% [markdown]
# #### Tensorflow Data

# %% [markdown]
# ##### from_tensor_slices

# %%
# Dataset
cache_dir = 'ds_cache'
train_cache = os.path.join(cache_dir, 'train')
val_cache = os.path.join(cache_dir, 'val')
test_cache = os.path.join(cache_dir, 'test')
Path(cache_dir).mkdir(parents=True, exist_ok=True)

train_ds = tf.data.Dataset.from_tensor_slices((train_df[column_image], lb.transform(train_df[column_label]))).map(
    lambda x, y: (preprocess_image(x, color_mode, target_size), y), num_parallel_calls=tf.data.AUTOTUNE
).cache(
    train_cache
).map(
    lambda x, y: (train_augmentation(x), y), num_parallel_calls=tf.data.AUTOTUNE
).shuffle(
    len(train_df[column_label])
).batch(
    BS, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((val_df[column_image], lb.transform(val_df[column_label]))).map(
    lambda x, y: (preprocess_image(x, color_mode, target_size), y), num_parallel_calls=tf.data.AUTOTUNE
).cache(
    val_cache
).map(
    lambda x, y: (val_augmentation(x), y), num_parallel_calls=tf.data.AUTOTUNE
).shuffle(
    len(val_df[column_label])
).batch(
    BS, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((test_df[column_image], lb.transform(test_df[column_label]))).map(
    lambda x, y: (preprocess_image(x, color_mode, target_size), y), num_parallel_calls=tf.data.AUTOTUNE
).cache(
    test_cache
).map(
    lambda x, y: (val_augmentation(x), y), num_parallel_calls=tf.data.AUTOTUNE
).batch(
    BS, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# #### Samples

# %%
# # Sample
# for sample_images, sample_labels in train_ds.take(1):
#   for i in range(10):
#     plt.figure()
#     plt.imshow(sample_images[i])
#     plt.title(classes[np.argmax(sample_labels[i])])
#   break

# %% [markdown]
# ### From Single image folder without shuffle

# %% [markdown]
# #### Image Data Generator flow_from_directory

# %%
# datagen = ImageDataGenerator(
#     rescale=1./255,
#     rotation_range=45,
#     shear_range=0.15,
#     zoom_range=0.2,
#     vertical_flip=True,
#     horizontal_flip=True,
#     validation_split=0.2,
# )

# train_generator = datagen.flow_from_directory(
#     LABELLED_DIR,
#     target_size=target_size,
#     batch_size=BS,
#     subset='training',
# )

# val_generator = datagen.flow_from_directory(
#     LABELLED_DIR,
#     target_size=target_size,
#     batch_size=BS//2,
#     subset='validation',
# )

# %% [markdown]
# #### image_dataset_from_directory

# %%
# # Split data into training and validation
# ds_kwargs = {'directory': LABELLED_DIR,
#            'batch_size': BS,
#            'image_size': target_size,
#            'validation_split': 0.15,
#            'seed': 123,
#            'label_mode': 'categorical',
#            }
# train_ds = tf.keras.preprocessing.image_dataset_from_directory(**ds_kwargs,
#                                                                subset='training',
#                                                                ).map(lambda x, y: (train_augmentation(x), y), num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
# val_ds = tf.keras.preprocessing.image_dataset_from_directory(**ds_kwargs,
#                                                                subset='validation',
#                                                                ).map(lambda x, y: (val_augmentation(x), y), num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ### From Separated Training & Validation Folder

# %%
# training_datagen = ImageDataGenerator(
#     rescale=1./255,
#     rotation_range=45,
#     shear_range=0.15,
#     zoom_range=0.2,
#     vertical_flip=True,
#     horizontal_flip=True,
# )

# val_datagen = ImageDataGenerator(
#     rescale=1./255,
# )

# train_generator = training_datagen.flow_from_directory(
#     TRAINING_DIR,
#     target_size=target_size,
#     batch_size=BS,
# )

# val_generator = val_datagen.flow_from_directory(
#     VALIDATION_DIR,
#     target_size=target_size,
#     batch_size=BS,
# )

# %% [markdown]
# ## Assign same dataset variables

# %%
try:
    train_ds = train_generator
    val_ds = val_generator
    test_ds = test_generator
except:
    pass

# %% [markdown]
# # Model

# %% [markdown]
# ## Variables

# %%
chan_dim = -1
input_shape = target_size + (depth,)
if K.image_data_format() == 'channels_first':
    input_shape = (depth,) + target_size
    chan_dim = 1

# %% [markdown]
# ## Transfer Learning

# %%
# Transfer Learning
base_model = keras.applications.EfficientNetB3(
    include_top=False,
    weights='imagenet',
    input_shape=input_shape,
    pooling='max',
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 0s 0us/step
# 43950080/43941136 [==============================] - 0s 0us/step

# %%
# base_model.trainable = False

# %%
# base_model.summary()

# %% [markdown]
# ### With transfer learning

# %%
# # No additional Input layer
# inputs = base_model.input
# x = base_model(inputs, training=False)
# x = Dense(1024, activation=tf.nn.relu)(x)
# x = Dropout(0.2)(x)
# outputs = Dense(n_classes, activation=tf.nn.softmax)(x)
# model = Model(inputs=inputs, outputs=outputs)
# model.summary()

# %%
# # Sequential - loss: 0.5479 - accuracy: 0.7955 - val_loss: 0.6703 - val_accuracy: 0.7899 - lr: 9.0000e-04
# model = Sequential([
#   base_model,
#   Conv2D(128, 3, padding='same'),
#   BatchNormalization(),
#   Activation(tf.nn.relu),
#   Dropout(0.2),
#   Conv2D(64, 3, padding='same', activation=tf.nn.relu),
#   GlobalAveragePooling2D(),
#   Dense(1024, activation=tf.nn.relu),
#   Dense(256, activation=tf.nn.relu),
#   Dense(n_classes, activation=tf.nn.softmax)
# ])
# model.summary()

# %%
# # Sequential - loss: 0.5193 - accuracy: 0.8063 - val_loss: 0.6546 - val_accuracy: 0.7779 - lr: 9.0000e-05
# model = Sequential([
#   base_model,
#   Conv2D(128, 3, padding='same'),
#   BatchNormalization(),
#   Activation(tf.nn.relu),
#   Dropout(0.2),
#   Conv2D(64, 3, padding='same', activation=tf.nn.relu),
#   MaxPooling2D(2, 2),
#   Conv2D(64, 3, padding='same', activation=tf.nn.relu),
#   GlobalAveragePooling2D(),
#   # Dense(1024, activation=tf.nn.relu),
#   Dense(256, activation=tf.nn.relu),
#   Dense(n_classes, activation=tf.nn.softmax)
# ])
# model.summary()

# %%
# # Sequential - loss: 0.5770 - accuracy: 0.7780 - val_loss: 0.6471 - val_accuracy: 0.7798 - lr: 3.0000e-04
# model = Sequential([
#   base_model,
#   Conv2D(128, 3, padding='same'),
#   BatchNormalization(axis=chan_dim),
#   Activation(tf.nn.relu),
#   Dropout(0.1),
#   Conv2D(64, 3, padding='same', activation=tf.nn.relu),
#   MaxPooling2D(2, padding='same'),
#   Conv2D(64, 3, padding='same'),
#   BatchNormalization(axis=chan_dim),
#   Activation(tf.nn.relu),
#   Dropout(0.1),
#   Conv2D(64, 3, padding='same', activation=tf.nn.relu),
#   GlobalAveragePooling2D(),
#   Dense(256, activation=tf.nn.relu),
#   Dense(n_classes, activation=tf.nn.softmax)
# ])
# model.summary()

# %%
# # Sequential - loss: 0.5025 - accuracy: 0.8123 - val_loss: 0.6445 - val_accuracy: 0.7897 - lr: 9.0000e-05
# # Sequential - loss: 0.5629 - accuracy: 0.7832 - val_loss: 0.6472 - val_accuracy: 0.7738 - lr: 3.0000e-04
# # no decay - loss: 0.5694 - accuracy: 0.7794 - val_loss: 0.6564 - val_accuracy: 0.7718 - lr: 9.0000e-05
# model = Sequential([
#   base_model,
#   Conv2D(128, 3, padding='same'),
#   BatchNormalization(axis=chan_dim),
#   Activation(tf.nn.relu),
#   Dropout(0.1),
#   Conv2D(64, 3, padding='same', activation=tf.nn.relu),
#   MaxPooling2D(2, padding='same'),
#   # Conv2D(64, 3, padding='same'),
#   # BatchNormalization(axis=chan_dim),
#   # Activation(tf.nn.relu),
#   # Dropout(0.1),
#   Conv2D(64, 3, padding='same', activation=tf.nn.relu),
#   GlobalAveragePooling2D(),
#   Dense(256, activation=tf.nn.relu),
#   Dense(n_classes, activation=tf.nn.softmax)
# ])
# model.summary()

# %%
model = Sequential([
    base_model,
    BatchNormalization(axis=chan_dim, momentum=0.99, epsilon=1e-3),
    Dense(256, activation=tf.nn.relu, kernel_regularizer=keras.regularizers.l2(l=16e-3),
          activity_regularizer=keras.regularizers.l1(6e-3), bias_regularizer=keras.regularizers.l1(6e-3)),
    Dropout(0.4, seed=123),
    Dense(n_classes, activation=tf.nn.softmax)
])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb3 (Functional)  (None, 1536)             10783535
#
#  batch_normalization (BatchN  (None, 1536)             6144
#  ormalization)
#
#  dense (Dense)               (None, 256)               393472
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 14)                3598
#
# =================================================================
# Total params: 11,186,749
# Trainable params: 11,096,374
# Non-trainable params: 90,375
# _________________________________________________________________

# %% [markdown]
# ## Optimizer & Compile

# %%
# optimizer = Adam(learning_rate=LEARNING_RATE, decay=LEARNING_RATE / EPOCHS)
optimizer = optimizers.Adamax(learning_rate=LEARNING_RATE)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# # Training

# %%
BEST_MODEL = os.path.join('saved_model', 'best_model')
BEST_MODEL_H5 = BEST_MODEL + '.h5'
BEST_MODEL_SAVE_PATH = os.path.join(DRIVE_DIR, BEST_MODEL_H5)


def get_model_checkpoint(metrics_values={}):
    def evaluated_metrics(logs): return [
        logs[key] > val if 'accuracy' in key else logs[key] < val for key, val in metrics_values.items()]

    class MyModelCheckpoint(tf.keras.callbacks.ModelCheckpoint):
        def on_epoch_end(self, epoch, logs):
            if False not in evaluated_metrics(logs):
                super().on_epoch_end(epoch, logs)
                global best_model
                best_model = self.model
                if is_colab:
                    shutil.copyfile(BEST_MODEL_H5, BEST_MODEL_SAVE_PATH)

    monitor = 'val_loss' if not metrics_values.keys(
    ) else next(iter(metrics_values.keys()))
    return MyModelCheckpoint(
        BEST_MODEL_H5,
        verbose=1,
        save_best_only=True,
        monitor=monitor)

# %%
model_checkpoint = get_model_checkpoint({'val_loss': 0.7})

# %%
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(factor=0.3,
                                                               patience=5,
                                                               min_lr=1e-5)

# %%
early_stop_patience = max(((EPOCHS*0.2)//1, 10))
early_stopping = tf.keras.callbacks.EarlyStopping(patience=early_stop_patience)

# %%
# # If we are looking for the best learning rate
# learning_rate_schedule = tf.keras.callbacks.LearningRateScheduler(
#     lambda epoch: LEARNING_RATE * 10**(epoch/2)
# )

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[model_checkpoint, learning_rate_reduction, early_stopping],
    # # If we are looking for the best learning rate
    # callbacks=[learning_rate_schedule],
)
# Out:
# Epoch 1/100
# 346/346 [==============================] - 386s 555ms/step - loss: 5.7377 - accuracy: 0.8244 - val_loss: 6.4275 - val_accuracy: 0.1212 - lr: 0.0010
# Epoch 2/100
# 346/346 [==============================] - 278s 529ms/step - loss: 2.4111 - accuracy: 0.9177 - val_loss: 3.3684 - val_accuracy: 0.3268 - lr: 0.0010
# Epoch 3/100
# 346/346 [==============================] - 276s 529ms/step - loss: 1.1265 - accuracy: 0.9344 - val_loss: 3.5128 - val_accuracy: 0.1254 - lr: 0.0010
# Epoch 4/100
# 346/346 [==============================] - 276s 529ms/step - loss: 0.6585 - accuracy: 0.9441 - val_loss: 1.7035 - val_accuracy: 0.5640 - lr: 0.0010
# Epoch 5/100
# 346/346 [==============================] - 276s 529ms/step - loss: 0.5066 - accuracy: 0.9451 - val_loss: 5.3720 - val_accuracy: 0.0392 - lr: 0.0010
# Epoch 6/100
# 346/346 [==============================] - 276s 528ms/step - loss: 0.4374 - accuracy: 0.9504 - val_loss: 21.1874 - val_accuracy: 0.0589 - lr: 0.0010
# Epoch 7/100
# 346/346 [==============================] - 280s 541ms/step - loss: 0.3918 - accuracy: 0.9555 - val_loss: 3.4179 - val_accuracy: 0.1143 - lr: 0.0010
# Epoch 8/100
# 346/346 [==============================] - 276s 528ms/step - loss: 0.3627 - accuracy: 0.9593 - val_loss: 3.0301 - val_accuracy: 0.3200 - lr: 0.0010
# Epoch 9/100
# 346/346 [==============================] - 276s 528ms/step - loss: 0.3443 - accuracy: 0.9603 - val_loss: 3.2194 - val_accuracy: 0.0546 - lr: 0.0010
# Epoch 10/100
# 346/346 [==============================] - 276s 529ms/step - loss: 0.3086 - accuracy: 0.9682 - val_loss: 0.8657 - val_accuracy: 0.7756 - lr: 3.0000e-04
# Epoch 11/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.9730
# Epoch 11: val_loss improved from inf to 0.43671, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 277s 532ms/step - loss: 0.2817 - accuracy: 0.9730 - val_loss: 0.4367 - val_accuracy: 0.9181 - lr: 3.0000e-04
# Epoch 12/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2778 - accuracy: 0.9708
# Epoch 12: val_loss improved from 0.43671 to 0.33399, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 278s 532ms/step - loss: 0.2778 - accuracy: 0.9708 - val_loss: 0.3340 - val_accuracy: 0.9352 - lr: 3.0000e-04
# Epoch 13/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2654 - accuracy: 0.9724
# Epoch 13: val_loss did not improve from 0.33399
# 346/346 [==============================] - 276s 528ms/step - loss: 0.2654 - accuracy: 0.9724 - val_loss: 0.3378 - val_accuracy: 0.9369 - lr: 3.0000e-04
# Epoch 14/100
# 346/346 [==============================] - 276s 529ms/step - loss: 0.2595 - accuracy: 0.9738 - val_loss: 2.5425 - val_accuracy: 0.2790 - lr: 3.0000e-04
# Epoch 15/100
# 346/346 [==============================] - 277s 528ms/step - loss: 0.2597 - accuracy: 0.9719 - val_loss: 1.6036 - val_accuracy: 0.5862 - lr: 3.0000e-04
# Epoch 16/100
# 346/346 [==============================] - 277s 528ms/step - loss: 0.2427 - accuracy: 0.9769 - val_loss: 0.7272 - val_accuracy: 0.8123 - lr: 3.0000e-04
# Epoch 17/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2387 - accuracy: 0.9771
# Epoch 17: val_loss did not improve from 0.33399
# 346/346 [==============================] - 276s 528ms/step - loss: 0.2387 - accuracy: 0.9771 - val_loss: 0.4817 - val_accuracy: 0.8763 - lr: 3.0000e-04
# Epoch 18/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2342 - accuracy: 0.9772
# Epoch 18: val_loss improved from 0.33399 to 0.28630, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 281s 542ms/step - loss: 0.2342 - accuracy: 0.9772 - val_loss: 0.2863 - val_accuracy: 0.9488 - lr: 9.0000e-05
# Epoch 19/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2278 - accuracy: 0.9775
# Epoch 19: val_loss did not improve from 0.28630
# 346/346 [==============================] - 279s 539ms/step - loss: 0.2278 - accuracy: 0.9775 - val_loss: 0.3177 - val_accuracy: 0.9386 - lr: 9.0000e-05
# Epoch 20/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2194 - accuracy: 0.9801
# Epoch 20: val_loss did not improve from 0.28630
# 346/346 [==============================] - 276s 528ms/step - loss: 0.2194 - accuracy: 0.9801 - val_loss: 0.3075 - val_accuracy: 0.9411 - lr: 9.0000e-05
# Epoch 21/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.9771
# Epoch 21: val_loss improved from 0.28630 to 0.25766, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 276s 529ms/step - loss: 0.2247 - accuracy: 0.9771 - val_loss: 0.2577 - val_accuracy: 0.9608 - lr: 9.0000e-05
# Epoch 22/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2218 - accuracy: 0.9780
# Epoch 22: val_loss did not improve from 0.25766
# 346/346 [==============================] - 279s 537ms/step - loss: 0.2218 - accuracy: 0.9780 - val_loss: 0.4278 - val_accuracy: 0.9070 - lr: 9.0000e-05
# Epoch 23/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2183 - accuracy: 0.9789
# Epoch 23: val_loss did not improve from 0.25766
# 346/346 [==============================] - 274s 525ms/step - loss: 0.2183 - accuracy: 0.9789 - val_loss: 0.2875 - val_accuracy: 0.9539 - lr: 9.0000e-05
# Epoch 24/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2163 - accuracy: 0.9802
# Epoch 24: val_loss did not improve from 0.25766
# 346/346 [==============================] - 276s 525ms/step - loss: 0.2163 - accuracy: 0.9802 - val_loss: 0.3251 - val_accuracy: 0.9326 - lr: 9.0000e-05
# Epoch 25/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2112 - accuracy: 0.9818
# Epoch 25: val_loss improved from 0.25766 to 0.25576, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 275s 528ms/step - loss: 0.2112 - accuracy: 0.9818 - val_loss: 0.2558 - val_accuracy: 0.9633 - lr: 9.0000e-05
# Epoch 26/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9811
# Epoch 26: val_loss improved from 0.25576 to 0.24756, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 277s 532ms/step - loss: 0.2117 - accuracy: 0.9811 - val_loss: 0.2476 - val_accuracy: 0.9625 - lr: 9.0000e-05
# Epoch 27/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2075 - accuracy: 0.9813
# Epoch 27: val_loss did not improve from 0.24756
# 346/346 [==============================] - 276s 529ms/step - loss: 0.2075 - accuracy: 0.9813 - val_loss: 0.2688 - val_accuracy: 0.9531 - lr: 9.0000e-05
# Epoch 28/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2063 - accuracy: 0.9823
# Epoch 28: val_loss did not improve from 0.24756
# 346/346 [==============================] - 280s 540ms/step - loss: 0.2063 - accuracy: 0.9823 - val_loss: 0.2927 - val_accuracy: 0.9471 - lr: 9.0000e-05
# Epoch 29/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2019 - accuracy: 0.9819
# Epoch 29: val_loss did not improve from 0.24756
# 346/346 [==============================] - 276s 529ms/step - loss: 0.2019 - accuracy: 0.9819 - val_loss: 0.3138 - val_accuracy: 0.9352 - lr: 9.0000e-05
# Epoch 30/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2055 - accuracy: 0.9813
# Epoch 30: val_loss improved from 0.24756 to 0.24347, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 278s 532ms/step - loss: 0.2055 - accuracy: 0.9813 - val_loss: 0.2435 - val_accuracy: 0.9590 - lr: 9.0000e-05
# Epoch 31/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2016 - accuracy: 0.9818
# Epoch 31: val_loss did not improve from 0.24347
# 346/346 [==============================] - 277s 530ms/step - loss: 0.2016 - accuracy: 0.9818 - val_loss: 0.2889 - val_accuracy: 0.9445 - lr: 9.0000e-05
# Epoch 32/100
# 346/346 [==============================] - ETA: 0s - loss: 0.2044 - accuracy: 0.9812
# Epoch 32: val_loss did not improve from 0.24347
# 346/346 [==============================] - 276s 529ms/step - loss: 0.2044 - accuracy: 0.9812 - val_loss: 0.2647 - val_accuracy: 0.9505 - lr: 9.0000e-05
# Epoch 33/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9828
# Epoch 33: val_loss did not improve from 0.24347
# 346/346 [==============================] - 276s 528ms/step - loss: 0.1980 - accuracy: 0.9828 - val_loss: 0.2529 - val_accuracy: 0.9565 - lr: 9.0000e-05
# Epoch 34/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1947 - accuracy: 0.9844
# Epoch 34: val_loss did not improve from 0.24347
# 346/346 [==============================] - 278s 530ms/step - loss: 0.1947 - accuracy: 0.9844 - val_loss: 0.5914 - val_accuracy: 0.8549 - lr: 9.0000e-05
# Epoch 35/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 0.9848
# Epoch 35: val_loss did not improve from 0.24347
# 346/346 [==============================] - 279s 530ms/step - loss: 0.1936 - accuracy: 0.9848 - val_loss: 0.2880 - val_accuracy: 0.9420 - lr: 9.0000e-05
# Epoch 36/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1923 - accuracy: 0.9845
# Epoch 36: val_loss improved from 0.24347 to 0.20968, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 279s 532ms/step - loss: 0.1923 - accuracy: 0.9845 - val_loss: 0.2097 - val_accuracy: 0.9735 - lr: 2.7000e-05
# Epoch 37/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1916 - accuracy: 0.9830
# Epoch 37: val_loss improved from 0.20968 to 0.20788, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 280s 533ms/step - loss: 0.1916 - accuracy: 0.9830 - val_loss: 0.2079 - val_accuracy: 0.9744 - lr: 2.7000e-05
# Epoch 38/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9832
# Epoch 38: val_loss did not improve from 0.20788
# 346/346 [==============================] - 277s 529ms/step - loss: 0.1892 - accuracy: 0.9832 - val_loss: 0.2360 - val_accuracy: 0.9633 - lr: 2.7000e-05
# Epoch 39/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9842
# Epoch 39: val_loss did not improve from 0.20788
# 346/346 [==============================] - 276s 529ms/step - loss: 0.1892 - accuracy: 0.9842 - val_loss: 0.2184 - val_accuracy: 0.9718 - lr: 2.7000e-05
# Epoch 40/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1927 - accuracy: 0.9832
# Epoch 40: val_loss did not improve from 0.20788
# 346/346 [==============================] - 277s 529ms/step - loss: 0.1927 - accuracy: 0.9832 - val_loss: 0.2142 - val_accuracy: 0.9701 - lr: 2.7000e-05
# Epoch 41/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9836
# Epoch 41: val_loss improved from 0.20788 to 0.20188, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 277s 531ms/step - loss: 0.1907 - accuracy: 0.9836 - val_loss: 0.2019 - val_accuracy: 0.9744 - lr: 2.7000e-05
# Epoch 42/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1891 - accuracy: 0.9849
# Epoch 42: val_loss did not improve from 0.20188
# 346/346 [==============================] - 275s 527ms/step - loss: 0.1891 - accuracy: 0.9849 - val_loss: 0.2215 - val_accuracy: 0.9701 - lr: 2.7000e-05
# Epoch 43/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9835
# Epoch 43: val_loss did not improve from 0.20188
# 346/346 [==============================] - 280s 539ms/step - loss: 0.1889 - accuracy: 0.9835 - val_loss: 0.2212 - val_accuracy: 0.9676 - lr: 2.7000e-05
# Epoch 44/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9840
# Epoch 44: val_loss did not improve from 0.20188
# 346/346 [==============================] - 276s 529ms/step - loss: 0.1881 - accuracy: 0.9840 - val_loss: 0.2062 - val_accuracy: 0.9718 - lr: 2.7000e-05
# Epoch 45/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1882 - accuracy: 0.9838
# Epoch 45: val_loss improved from 0.20188 to 0.19964, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 277s 531ms/step - loss: 0.1882 - accuracy: 0.9838 - val_loss: 0.1996 - val_accuracy: 0.9735 - lr: 2.7000e-05
# Epoch 46/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1862 - accuracy: 0.9847
# Epoch 46: val_loss did not improve from 0.19964
# 346/346 [==============================] - 276s 528ms/step - loss: 0.1862 - accuracy: 0.9847 - val_loss: 0.2171 - val_accuracy: 0.9693 - lr: 2.7000e-05
# Epoch 47/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1871 - accuracy: 0.9839
# Epoch 47: val_loss did not improve from 0.19964
# 346/346 [==============================] - 276s 528ms/step - loss: 0.1871 - accuracy: 0.9839 - val_loss: 0.2220 - val_accuracy: 0.9633 - lr: 2.7000e-05
# Epoch 48/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1853 - accuracy: 0.9849
# Epoch 48: val_loss did not improve from 0.19964
# 346/346 [==============================] - 278s 529ms/step - loss: 0.1853 - accuracy: 0.9849 - val_loss: 0.2363 - val_accuracy: 0.9625 - lr: 2.7000e-05
# Epoch 49/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1867 - accuracy: 0.9836
# Epoch 49: val_loss did not improve from 0.19964
# 346/346 [==============================] - 276s 528ms/step - loss: 0.1867 - accuracy: 0.9836 - val_loss: 0.2490 - val_accuracy: 0.9539 - lr: 2.7000e-05
# Epoch 50/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9848
# Epoch 50: val_loss did not improve from 0.19964
# 346/346 [==============================] - 276s 528ms/step - loss: 0.1820 - accuracy: 0.9848 - val_loss: 0.2145 - val_accuracy: 0.9693 - lr: 2.7000e-05
# Epoch 51/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1813 - accuracy: 0.9855
# Epoch 51: val_loss improved from 0.19964 to 0.19745, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 279s 534ms/step - loss: 0.1813 - accuracy: 0.9855 - val_loss: 0.1974 - val_accuracy: 0.9761 - lr: 1.0000e-05
# Epoch 52/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9841
# Epoch 52: val_loss did not improve from 0.19745
# 346/346 [==============================] - 276s 528ms/step - loss: 0.1857 - accuracy: 0.9841 - val_loss: 0.1998 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 53/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1836 - accuracy: 0.9844
# Epoch 53: val_loss improved from 0.19745 to 0.19548, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 278s 532ms/step - loss: 0.1836 - accuracy: 0.9844 - val_loss: 0.1955 - val_accuracy: 0.9761 - lr: 1.0000e-05
# Epoch 54/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1815 - accuracy: 0.9852
# Epoch 54: val_loss did not improve from 0.19548
# 346/346 [==============================] - 277s 529ms/step - loss: 0.1815 - accuracy: 0.9852 - val_loss: 0.1978 - val_accuracy: 0.9753 - lr: 1.0000e-05
# Epoch 55/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1839 - accuracy: 0.9844
# Epoch 55: val_loss did not improve from 0.19548
# 346/346 [==============================] - 277s 528ms/step - loss: 0.1839 - accuracy: 0.9844 - val_loss: 0.1976 - val_accuracy: 0.9787 - lr: 1.0000e-05
# Epoch 56/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1830 - accuracy: 0.9851
# Epoch 56: val_loss did not improve from 0.19548
# 346/346 [==============================] - 276s 528ms/step - loss: 0.1830 - accuracy: 0.9851 - val_loss: 0.1971 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 57/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1825 - accuracy: 0.9857
# Epoch 57: val_loss did not improve from 0.19548
# 346/346 [==============================] - 276s 529ms/step - loss: 0.1825 - accuracy: 0.9857 - val_loss: 0.1970 - val_accuracy: 0.9770 - lr: 1.0000e-05
# Epoch 58/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1855 - accuracy: 0.9845
# Epoch 58: val_loss did not improve from 0.19548
# 346/346 [==============================] - 276s 529ms/step - loss: 0.1855 - accuracy: 0.9845 - val_loss: 0.2037 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 59/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1846 - accuracy: 0.9832
# Epoch 59: val_loss did not improve from 0.19548
# 346/346 [==============================] - 275s 528ms/step - loss: 0.1846 - accuracy: 0.9832 - val_loss: 0.2124 - val_accuracy: 0.9693 - lr: 1.0000e-05
# Epoch 60/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1855 - accuracy: 0.9841
# Epoch 60: val_loss improved from 0.19548 to 0.19527, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 276s 531ms/step - loss: 0.1855 - accuracy: 0.9841 - val_loss: 0.1953 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 61/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1803 - accuracy: 0.9857
# Epoch 61: val_loss did not improve from 0.19527
# 346/346 [==============================] - 279s 530ms/step - loss: 0.1803 - accuracy: 0.9857 - val_loss: 0.1979 - val_accuracy: 0.9770 - lr: 1.0000e-05
# Epoch 62/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1816 - accuracy: 0.9858
# Epoch 62: val_loss did not improve from 0.19527
# 346/346 [==============================] - 277s 531ms/step - loss: 0.1816 - accuracy: 0.9858 - val_loss: 0.1971 - val_accuracy: 0.9753 - lr: 1.0000e-05
# Epoch 63/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1813 - accuracy: 0.9857
# Epoch 63: val_loss did not improve from 0.19527
# 346/346 [==============================] - 276s 530ms/step - loss: 0.1813 - accuracy: 0.9857 - val_loss: 0.1985 - val_accuracy: 0.9761 - lr: 1.0000e-05
# Epoch 64/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1812 - accuracy: 0.9848
# Epoch 64: val_loss did not improve from 0.19527
# 346/346 [==============================] - 276s 530ms/step - loss: 0.1812 - accuracy: 0.9848 - val_loss: 0.1985 - val_accuracy: 0.9753 - lr: 1.0000e-05
# Epoch 65/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1818 - accuracy: 0.9847
# Epoch 65: val_loss did not improve from 0.19527
# 346/346 [==============================] - 275s 529ms/step - loss: 0.1818 - accuracy: 0.9847 - val_loss: 0.1955 - val_accuracy: 0.9770 - lr: 1.0000e-05
# Epoch 66/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.9849
# Epoch 66: val_loss did not improve from 0.19527
# 346/346 [==============================] - 275s 527ms/step - loss: 0.1845 - accuracy: 0.9849 - val_loss: 0.1966 - val_accuracy: 0.9744 - lr: 1.0000e-05
# Epoch 67/100
# 346/346 [==============================] - ETA: 0s - loss: 0.1812 - accuracy: 0.9854
# Epoch 67: val_loss improved from 0.19527 to 0.19508, saving model to saved_model/best_model.h5
# 346/346 [==============================] - 277s 532ms/step - loss: 0.1812 - accuracy: 0.9854 - val_loss: 0.1951 - val_accuracy: 0.9770 - lr: 1.0000e-05

# %% [markdown]
# # Result

# %% [markdown]
# Plot the train and val curve

# %%
# # If we are looking for the best learning rate & to plot it
# plt.semilogx(history.history['lr'], history.history['loss'])
# plt.axis([1e-6, 1e-0, 0, 1.5])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()

plt.figure()

# Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %% [markdown]
# # Test

# %%
scores = model.evaluate(test_ds)
print(f"Test Accuracy: {scores[1]*100}")

# %%
# from tensorflow.keras.models import load_model
# best_model = load_model(BEST_MODEL_H5)
scores = best_model.evaluate(test_ds)
print(f"Best Accuracy: {scores[1]*100}")

# %% [markdown]
# # Save and Zip

# %%
MODEL_PATH = os.path.join('saved_model', 'model')
best_model.save(MODEL_PATH)
# !zip -r model.zip {MODEL_PATH}
